# %% [markdown]
# <a href="https://colab.research.google.com/github/Aabhiinavvv/Abhinav/blob/main/fake_news_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
import re
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
print(stopwords.words('french'))
# Out:
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui', 'sa', 'se', 'ses', 'son', 'sur', 'ta', 'te', 'tes', 'toi', 'ton', 'tu', 'un', 'une', 'vos', 'votre', 'vous', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'été', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'est', 'sommes', 'êtes', 'sont', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étions', 'étiez', 'étaient', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soyez', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eu', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'a
# ...

# %%
news_dataset = pd.read_csv("/content/archive (26).zip", compression='zip')

# %%
news_dataset.shape
# Out:
# (20000, 7)

# %%
news_dataset.head()
# Out:
#                                   title  \
# 0               Foreign Democrat final.
# 1   To offer down resource great point.
# 2          Himself church myself carry.
# 3                  You unit its should.
# 4  Billion believe employee summer how.
#
#                                                 text        date    source  \
# 0  more tax development both store agreement lawy...  2023-03-10  NY Times
# 1  probably guess western behind likely next inve...  2022-05-25  Fox News
# 2  them identify forward present success risk sev...  2022-09-01       CNN
# 3  phone which item yard Republican safe where po...  2023-02-07   Reuters
# 4  wonder myself fact difficult course forget exa...  2023-04-03       CNN
#
#                  author    category label
# 0          Paula George    Politics  real
# 1           Joseph Hill    Politics  fake
# 2        Julia Robinson    Business  fake
# 3  Mr. David Foster DDS     Science  fake
# 4         Austin Walker  Technology  fake

# %%
news_dataset.isnull().sum()
# Out:
# title          0
# text           0
# date           0
# source      1000
# author      1000
# category       0
# label          0
# dtype: int64

# %%
import pandas as pd

news_dataset = pd.read_csv('/content/archive (26).zip')
news_dataset = news_dataset.fillna('')

# %%
news_dataset['content'] = news_dataset['title'] + " " + news_dataset['text']
news_dataset = news_dataset[['content', 'label']]

news_dataset.head()
# Out:
#                                              content label
# 0  Foreign Democrat final. more tax development b...  real
# 1  To offer down resource great point. probably g...  fake
# 2  Himself church myself carry. them identify for...  fake
# 3  You unit its should. phone which item yard Rep...  fake
# 4  Billion believe employee summer how. wonder my...  fake

# %%
news_dataset['label'] = news_dataset['label'].map({'real': 1, 'fake': 0})

# %%
print(news_dataset['label'])
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 19995    0
# 19996    1
# 19997    1
# 19998    0
# 19999    0
# Name: label, Length: 20000, dtype: int64

# %%
print(news_dataset['content'])
# Out:
# 0        Foreign Democrat final. more tax development b...
# 1        To offer down resource great point. probably g...
# 2        Himself church myself carry. them identify for...
# 3        You unit its should. phone which item yard Rep...
# 4        Billion believe employee summer how. wonder my...
#                                ...
# 19995    House party born. hit and television I change ...
# 19996    Though nation people maybe price box. fear mos...
# 19997    Yet exist with experience unit. activity loss ...
# 19998    School wide itself item. term point general co...
# 19999    Offer chair cover senior born. remain pressure...
# Name: content, Length: 20000, dtype: object

# %%
X = news_dataset.drop(columns = 'label' , axis = 1)

# %%
Y = news_dataset['label']

# %%
port_stem = PorterStemmer()

# %%
from nltk.stem.porter import PorterStemmer
import re

ps = PorterStemmer()

def stemming(text):
    review = re.sub('[^a-zA-Z]', ' ', text)
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review]
    return " ".join(review)

# %%
news_dataset['content'] = news_dataset['content'].apply(stemming)

# %%
print(news_dataset['content'])
# Out:
# 0        foreign democrat final more tax develop both s...
# 1        to offer down resourc great point probabl gues...
# 2        himself church myself carri them identifi forw...
# 3        you unit it should phone which item yard repub...
# 4        billion believ employ summer how wonder myself...
#                                ...
# 19995    hou parti born hit and televi i chang veri our...
# 19996    though nation peopl mayb price box fear most m...
# 19997    yet exist with experi unit activ loss veri pro...
# 19998    school wide itself item term point gener commo...
# 19999    offer chair cover senior born remain pressur g...
# Name: content, Length: 20000, dtype: object

# %%
X = news_dataset['content'].values
Y = news_dataset['label'].values

# %%
print(X)
# Out:
# ['foreign democrat final more tax develop both store agreement lawyer hear outsid continu reach differ yeah figur your power fear identifi there protect secur great nation noth fast stori whi late nearli bit cost tough sinc question to power almost futur young confer behind ahead build teach million box receiv mr risk benefit month compar environ class imagin you vote commun reason set onc idea him answer mani how purpo deep train game own true languag garden of partner result face militari discov discov data glass bed maintain test way develop across top cultur glass ye deci hope necessari as trade organ talk debat peac stay commun develop six wide write itself sever fight teach billion for common fear we person church establish store kind hundr debat hotel cut sister audienc sound case that stay within inform troubl be debat great themselv respon forc peopl hundr bar miss other sometim build room interest howev charg what especi north no especi us travel industri about includ face 
# ...

# %%
print(Y)
# Out:
# [1 0 0 ... 1 0 0]

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(X)
X = vectorizer.transform(X)

# %%
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 4445697 stored elements and shape (20000, 936)>
#   Coords	Values
#   (0, 2)	0.06083462566106287
#   (0, 7)	0.060526539824824414
#   (0, 8)	0.060311053798038805
#   (0, 21)	0.06115743762135015
#   (0, 26)	0.060759906983879376
#   (0, 27)	0.06083462566106287
#   (0, 31)	0.06054238126525003
#   (0, 33)	0.06101703336146574
#   (0, 46)	0.06099550347650642
#   (0, 53)	0.06085601549905123
#   (0, 60)	0.06093102636356013
#   (0, 67)	0.06076523653152943
#   (0, 78)	0.06007669205672059
#   (0, 80)	0.060616442827377874
#   (0, 85)	0.061114151113257374
#   (0, 89)	0.12182986677928377
#   (0, 91)	0.060882778910961076
#   (0, 98)	0.06101703336146574
#   (0, 99)	0.060311053798038805
#   (0, 100)	0.060706674755885696
#   (0, 107)	0.060600553758866534
#   (0, 108)	0.06111955777373167
#   (0, 114)	0.09319131667140185
#   (0, 130)	0.12259729157160629
#   (0, 142)	0.06102241877073589
#   :	:
#   (19999, 838)	0.06103930548003399
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# %%
model = LogisticRegression()

# %%
model.fit(X_train ,Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction =model.predict(X_train)
training_accuracy = accuracy_score(X_train_prediction,Y_train )

# %%
print("Accuracy Score Of The Training Data : ", training_accuracy)
# Out:
# Accuracy Score Of The Training Data :  0.601125

# %%
X_test_prediction =model.predict(X_test)
testing_accuracy = accuracy_score(X_test_prediction,Y_test )

# %%
print("accuracy score of testing data is " , testing_accuracy)
# Out:
# accuracy score of testing data is  0.5035

# %% [markdown]
# i got these score because of not using advance feature of preprocessing in nlp. if i use advance and better feature then i got accuracy of 90+%. as i'm in learning phase so right now i'm using this only

# %% [markdown]
# Predicting The System

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    news_dataset['content'],
    news_dataset['label'],
    test_size=0.2,
    random_state=42,
    stratify=news_dataset['label']
)

# %%
X_train_vectors = vectorizer.fit_transform(X_train)
X_test_vectors = vectorizer.transform(X_test)

# %%
sample_news = X_test.iloc[0]
vectorized_input = vectorizer.transform([sample_news])

prediction = model.predict(vectorized_input)[0]
probability = model.predict_proba(vectorized_input)[0][prediction] * 100

print("Prediction:", prediction)
print(f"Confidence: {probability:.2f}%")

if prediction == 0:
    print("The News Is Real")
else:
    print("The News Is Fake")
# Out:
# Prediction: 1
# Confidence: 58.77%
# The News Is Fake

# %%
print(Y_test[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3692497802.py in <cell line: 0>()
# ----> 1 print(Y_test[0])
#
# ...

# %%
def predict_news(text):
    if not text or text.strip()=="":
        return "⚠️ Please enter some text."

    # Preprocess
    cleaned = preprocess(text)

    # Vectorize
    vectorized = vectorizer.transform([cleaned])

    # Predict
    prediction = model.predict(vectorized)[0]
    confidence = model.predict_proba(vectorized)[0][prediction] * 100

    # Return readable result
    if prediction == 0:
        return f"🟦 REAL NEWS ({confidence:.2f}% confidence)"
    else:
        return f"🟥 FAKE NEWS ({confidence:.2f}% confidence)"

# %%
import joblib

joblib.dump(model, "fake_news_model.joblib")
joblib.dump(vectorizer, "vectorizer.joblib")

print("Model and vectorizer saved successfully!")
# Out:
# Model and vectorizer saved successfully!

# %%
import gradio as gr
import joblib
import re
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
import nltk


nltk.download('stopwords')

model = joblib.load("fake_news_model.joblib")
vectorizer = joblib.load("vectorizer.joblib")

ps = PorterStemmer()

def preprocess(text):
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = text.lower()
    text = text.split()
    text = [ps.stem(word) for word in text if word not in stopwords.words('english')]
    return " ".join(text)

def predict_news(text):
    if text.strip() == "":
        return "⚠️ Please enter a news sentence."

    cleaned = preprocess(text)
    vectorized = vectorizer.transform([cleaned])

    prediction = model.predict(vectorized)[0]
    confidence = model.predict_proba(vectorized)[0][prediction] * 100

    if prediction == 0:
        return f"🟦 REAL NEWS ({confidence:.2f}% confidence)"
    else:
        return f"🟥 FAKE NEWS ({confidence:.2f}% confidence)"

app = gr.Interface(
    fn=predict_news,
    inputs=gr.Textbox(lines=10, placeholder="Paste news text here..."),
    outputs="text",
    title="📰 Fake News Detector",
    description="Enter a news article or headline to check if it's Real or Fake."
)

app.launch(debug=True)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://6c9bbef564ea21d19d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6c9bbef564ea21d19d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ...
